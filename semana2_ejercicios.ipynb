# %% [markdown]
# <a href="https://colab.research.google.com/github/heisenberg304/aprendiendo-ml-cloud/blob/info_ml/semana2_ejercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class auto:
  def __init__(self, color, kilometraje):
    pass
  def acelerar(self):
    pass

  def frenar(self):
    pass

class Toyota(auto):
  def __init__(self, nombre, costo, color, kilometraje):
    pass

  def acelerar(self):
    pass

  def frenar(self):
    pass
carro1 = Toyota("q","w","f", 100)
carro1.acelerar()
carro1.frenar()
print(carro1)

# %%
class A:
    def saludar(self):
        print("Hola desde A")

class B(A):
    def saludar(self):
        print("Antes")
        super().saludar()
        print("Después")

# Fix: Create an instance of B and call the method on the instance
instance_b = B()
instance_b.saludar()
print(B)

# %%
class Base:
    def __init__(self):
        print("Base")

class X(Base):
    def __init__(self):
        super().__init__()
        print("X")

class Y(Base):
    def __init__(self):
        super().__init__()
        print("Y")

class Z(X, Y):
    def __init__(self):
        super().__init__()  # sigue el MRO y llama a X -> Y -> Base
        print("Z")
instance_Z = Z()
print(instance_Z)

# %%
class Auto:
    def __init__(self, color: str, velocidad_actual: float=0, multiplicador: float=1):
        self.color = color
        self.velocidad_actual = velocidad_actual
        self.multiplicador = multiplicador
    def acelerar(self, aceleracion: float, tiempo: float) ->float:
        self.velocidad_actual += aceleracion*tiempo*self.multiplicador
        return f"La velocidad es esta = {self.velocidad_actual} m/s"
    def frenar(self, desaceleracion: float) ->float:
        self.velocidad_actual = max(0, self.velocidad_actual - desaceleracion)
        if self.velocidad_actual == 0:
            return "El auto se ha detenido por completo"
        return f"La velocidad actual es:{self.velocidad_actual:.2f} m/s"
    def mostrar_estado(self) ->str:
        return f"La velocidad actual: {self.velocidad_actual:.2f} m/s"

class Deportivo(Auto):
    def __init__(self,color: str, velocidad_actual: float=0, nombre: str=None):
        super().__init__(color, velocidad_actual, multiplicador=1.5)
        self.nombre = nombre
    def turbo(self, extra:float):
        self.velocidad_actual += extra*self.multiplicador
        return f"Turbo activado: Velocidad actual: {self.velocidad_actual:.2f} m/s"

def carro_accion():
    Ferrari = Deportivo("Rojo", nombre="Ferrari")
    while True:
        opcion = input("Escoge accion: ").replace(" ", "").lower()
        if opcion == "acelerar":
            aceleracion = float(input("cuanto quires acelerar: ").replace(" ", "").lower())
            tiempo = float(input("por cuanto tiempo vas a acelerar: ").replace(" ", "").lower())
            print(Ferrari.acelerar(aceleracion, tiempo))
        elif opcion == "turbo":
            turbo = float(input("cuanto turbo daras: ").replace(" ", "").lower())
            print(Ferrari.turbo(turbo))
        elif opcion == "frenar":
            desaceleracion = float(input("que tanto frenaras: ").replace(" ", "").lower())
            print(Ferrari.frenar(desaceleracion))
        elif opcion == "mostrar":
            print(Ferrari.mostrar_estado())
        elif opcion == "terminar":
            print("saliendo del programa...")
            break
        else:
            print("Escoge la opcion correcta")
carro_accion()

# %% [markdown]
# el objeto se empieza a construir primero por la clase hija y luego toma los atributos de la clase padre con super()
# borrar el constructor de la clase hija y deja solo el constructor de la clase padre, igual permite crear a la clase hija pero  sin ninguna diferencia con la clase padre

# %%
#Forgive my english
class PlacentalMammals:
    viviparous = True
    with_a_placenta = True
    def __init__(self, average_lifespan:int, colour:str, skin_or_fur:str, diet: str, gender:str):
        self.average_lifespan = average_lifespan
        self.colour = colour
        self.skin_or_fur = skin_or_fur
        self.diet = diet
        self.gender = gender

    def appetite(self):
      return False
    def tired(self):
      return False
    def in_reproductive_state(self):
      return False
    def pregnant(self):
      if self.gender == "female" or self.gender == "hembra":    #only works in female
        return False
    def alive(self):
      return True
    def eat(self):
        if self.appetite() == True:
            return "The animal looks for food or start eating"
    def reproducirse(self):
        if self.in_reproductive_state() == True:
            if self.gender == "female" or self.gender == "hembra":
                self.pregnant() == True
                return "The female is gestating"
            return "The animnal will look for a mate to reproduce"
    def move(self):
        pass
    def sound(self):
        pass
    def comunicate(self):
        pass
    def sleep(self):
        if self.tired() == True:
            return "The animal start to sleep"
    def died(self):
        if self.alive() == False:
            return "Sadly, the animal has left the server"

class Cat(PlacentalMammals):                                                                                                                      # I use adult age as default
    def __init__(self, average_lifespan:int=17, colour:str=None, skin_or_fur:str="fur", diet:str="carnivore", gender:str=None, breed:str=None, name:str=None, age:int=3): #age in years
        super().__init__(average_lifespan, colour, skin_or_fur, diet, gender)
        self.breed = breed
        self.name = name
        self.age = age
       #here i will specify each of these actions, unique to each animal
    def move(self):
        return f"{self.name} start to walk"
    def sound(self):
        return f"{self.name} start to meow"
    def comunicate(self):
        return f"{self.name} start to move its ears, tail, and to meow and purr"

class Orca(PlacentalMammals):                                                                                                                      # I use adult age as default
    def __init__(self, average_lifespan:int=60, colour:str="Black and White", skin_or_fur:str="skin", diet:str="carnivore", gender:str=None, breed:str=None, name:str=None, age:int=15): #age in years
        super().__init__(average_lifespan, colour, skin_or_fur, diet, gender)
        self.breed = breed
        self.name = name
        self.age = age
       #here I will specify each of these actions, unique to each animal
    def move(self):
        return f"{self.name} start to swing"
    def sound(self):
        return f"{self.name} start to whistle and use echolocation"
    def comunicate(self):
        return f"{self.name} starts making pulsed calls, clicks, and whistling"

def print_animal(animal):
        objects = ["name", "age", "colour", "average_lifespan", "diet", "gender", "breed"]
        for obj in objects:
           print(f"{obj.capitalize()}: {getattr(animal, obj, None)}")

def get_animal_names(animals):
    return [animal.name for animal in animals]

def get_methods(obj):
    return [method for method in dir(obj) if not method.startswith('_') and callable(getattr(obj, method))]

def main():
    objects_cats = []
    objects_orca = []
    subclasses = PlacentalMammals.__subclasses__()
    while True:
        print(f"To finish, write 'finish'\nTo see animals, write 'see'\nTo do actions, write 'actions'\nAnimals avalaible: {[sub.__name__ for sub in subclasses]}")
        election = input("Choose one animal avalaible: ").replace(" ", "").lower()

        if election == "cat":
            print("---Creacion del gato---")
            nombre = input("Choose a name: ").replace(" ", "").lower()
            edad = input("Age: ").replace(" ", "").lower()
            color = input("Colour: ").replace(" ", "").lower()
            genero = input("Gender: ").replace(" ", "").lower()
            raza = input("Breed: ").replace(" ", "").lower()

            cats = Cat(name=nombre, age=edad, colour=color, gender=genero, breed=raza)
            objects_cats.append(cats)
            print_animal(cats)

        elif election == "orca":
            print("---Creacion de la orca---")
            nombre = input("Choose a name: ").replace(" ", "").lower()
            edad = input("Age: ").replace(" ", "").lower()
            genero = input("Gender: ").replace(" ", "").lower()
            raza = input("Breed: ").replace(" ", "").lower()

            orcas = Orca(name=nombre, age=edad, gender=genero, breed=raza)
            objects_orca.append(orcas)
            print_animal(orcas)

        elif election == "actions":
            print(f"Animals avalaible: {[sub.__name__ for sub in subclasses]}")
            what_animal = input("Choose the animal that going to do something: ").replace(" ", "").lower()
            if what_animal == "cat":
                print("--Cats avalaible--")
                print(get_animal_names(objects_cats))
                name_animal = input("What is the animal name: ").replace(" ", "").lower()
                if name_animal in get_animal_names(objects_cats):
                    print(f"Actions cat: {get_methods(Cat)}")
                    cat_action = input("Choose a action: ").replace(" ", "").lower()
                    if cat_action in get_methods(Cat):
                        cat_match = next(cc for cc in objects_cats if cc.name == name_animal)
                        action_result = getattr(cat_match, cat_action)()
                        print(action_result)
                else:
                    print(False)

            elif what_animal == "orca":
                print("--Orca avalaible--")
                print(get_animal_names(objects_orca))
                name_animal = input("What is the animal name: ").replace(" ", "").lower()
                if name_animal in get_animal_names(objects_orca):
                    print(f"Actions orca: {get_methods(Orca)}")
                    orca_action = input("Choose a action: ").replace(" ", "").lower()
                    if orca_action in get_methods(Cat):
                        orca_match = next(cc for cc in objects_orca if cc.name == name_animal)
                        action_result = getattr(orca_match, orca_action)()
                        print(action_result)

                else:
                    print(False)
            #I use a list of animals avalaible before because isn't a lots animals, I quite off that if it's a lots animals
            else:
                print("Try again")


        elif election == "finish":
            print("Going out...")
            break

        elif election == "see":
            print("To see cats, write 'cat'\nTo see orca, write 'orca'\nTo see both, write 'all'")
            choose = input("Choose cat, orca, both: ").replace(" ", "").lower()
            if choose == "cat":
                for g in objects_cats:
                    print_animal(g)
                    print("")

            elif choose == "orca":
                for o in objects_orca:
                    print_animal(o)
                    print("")

            elif choose == "all":
                print("All animals available:")
                print("--Cats--")
                for g in objects_cats:
                    print_animal(g)
                    print("")

                print("--Orca--")
                for o in objects_orca:
                    print_animal(o)
                    print("")
            else:
                print("Try again")
        else:
            print("Try again")

main()
